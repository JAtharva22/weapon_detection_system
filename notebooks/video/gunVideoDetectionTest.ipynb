# %%
import smtplib
import shutil
import cv2
import torch
import os
import time
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors
from google.colab.patches import cv2_imshow
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage

def send_email(sender_email, receiver_email, email_password, frame_filenames, video_link):
    """Send an email with a link to CCTV footage and attached images of detected frames."""
    msg = MIMEMultipart()
    msg['From'] = sender_email
    msg['To'] = receiver_email
    msg['Subject'] = "Gun Detection Alert"

    # HTML body with clickable video link
    body = f"""
    <html>
        <body>
            <p>Gun detected in the surveillance footage. Please check the images attached and click the link below for the CCTV footage.</p>
            <p><a href="{video_link}" target="_blank">View CCTV Footage</a></p>
        </body>
    </html>
    """
    msg.attach(MIMEText(body, 'html'))

    # Attach each image file to the email
    for filename in frame_filenames:
        try:
            with open(filename, 'rb') as img:
                mime_image = MIMEImage(img.read())
                mime_image.add_header('Content-Disposition', f'attachment; filename={os.path.basename(filename)}')
                msg.attach(mime_image)
        except FileNotFoundError:
            print(f"Error: File {filename} not found, skipping attachment.")

    # Send the email
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()  # Secure the connection
            server.login(sender_email, email_password)
            server.send_message(msg)
        print("Email sent successfully!")
    except Exception as e:
        print(f"Failed to send email: {e}")

# %%
# Object detection class
class ObjectDetection:
    def __init__(self, video_path, sender_email, receiver_email, email_password, live_video_link):
        """Initializes an ObjectDetection instance with a given video file path and email credentials."""
        self.video_path = video_path
        self.email_sent = False

        # Email credentials
        self.sender_email = sender_email
        self.receiver_email = receiver_email
        self.email_password = email_password

        # Model information
        self.model = YOLO("/content/best_manas_91.pt")

        # Visual information
        self.annotator = None
        self.start_time = 0
        self.end_time = 0

        # Device information
        self.device = "cuda" if torch.cuda.is_available() else "cpu"

        # Frame count and time tracking
        self.gun_frame_count = 0
        self.interval_start_time = time.time()  # Start timing for the 10-second interval

    def predict(self, im0):
        """Run prediction using a YOLO model for the input image im0."""
        results = self.model(im0)
        return results

    def plot_bboxes(self, results, im0):
        """Plots bounding boxes on an image given detection results; returns annotated image, class IDs, and confidence scores."""
        class_ids = []
        confidences = []  # List to store confidence scores
        self.annotator = Annotator(im0, 3, results[0].names)

        boxes = results[0].boxes.xyxy.cpu()  # Bounding box coordinates
        clss = results[0].boxes.cls.cpu().tolist()  # Class labels (as indices)
        confs = results[0].boxes.conf.cpu().tolist()  # Confidence scores
        names = results[0].names  # Class names

        for box, cls, conf in zip(boxes, clss, confs):
            class_ids.append(cls)
            confidences.append(f"{conf:.2f}")  # Append confidence score formatted to 2 decimal places
            label = f"{names[int(cls)]} {conf:.2f}"  # Include confidence in the label
            self.annotator.box_label(box, label=label, color=colors(int(cls), True))

        return im0, class_ids, confidences

    def __call__(self):
        """Run object detection on video frames from a video file, plotting and showing the results."""
        cap = cv2.VideoCapture(self.video_path)  # Load video from the file
        assert cap.isOpened()
        output_dir = '/content/safe'
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        count = 0  # Initialize frame count
        detected_frames = []  # List to store saved frame file paths

        while True:
            # if self.email_sent:
            #     break

            self.start_time = time.time()
            ret, im0 = cap.read()
            if not ret:  # If no more frames are available, break the loop
                break

            results = self.predict(im0)
            im0, class_ids, confidences = self.plot_bboxes(results, im0)

            # Check if gun class (class '0') is detected
            if 0 in class_ids or 1 in class_ids:
                for cls, conf in zip(class_ids, confidences):
                    if (cls == 0 or cls == 1) and float(conf) > 0.5:  # Check if it's a gun class and confidence > 50%
                        self.gun_frame_count += 1  # Count frames with gun detection
                        frame_filename = os.path.join(output_dir, f"frame_{count:04d}.jpg")
                        cv2.imwrite(frame_filename, im0)  # Save the frame with gun detection
                        detected_frames.append(frame_filename)
                        break  # Break after first match since frame is already saved

            if self.gun_frame_count >= 10:
                send_email(self.sender_email, self.receiver_email, self.email_password, detected_frames[-10:], live_video_link)  # Send last 10 detected frames
                self.email_sent = True

            # Check if 10 seconds have passed
            if time.time() - self.interval_start_time >= 10:
                # If gun detected in at least 5 frames within 10 seconds, send an email
                # Clear the folder after sending the email
                shutil.rmtree(output_dir)  # Remove the folder and its contents
                os.makedirs(output_dir)  # Recreate an empty folder
                detected_frames.clear()  # Clear the list of detected frames

                # Reset the interval and frame count after each 10 seconds
                self.interval_start_time = time.time()
                self.gun_frame_count = 0  # Reset for the next 10-second interval

            count += 1
            if cv2.waitKey(5) & 0xFF == 27:  # Press 'ESC' to exit
                break

        cap.release()
        cv2.destroyAllWindows()

# Example usage of the class
# Replace with actual values for sender, receiver, and email password
sender_email = "manas.divekar76@gmail.com"  # Replace with your email
receiver_email = "me.atharvajadhav@gmail.com"  # Replace with receiver's email
email_password = "jemu imks maqm kaow"  # Replace with your email password
video_path = '/content/armed_robbery_raw1.mp4'  # Path to your video
live_video_link = "http://127.0.0.1:5000/"  # Replace with your actual video link

# Initialize object detection
object_detection = ObjectDetection(video_path, sender_email, receiver_email, email_password, live_video_link)
# Run the detection
object_detection()
# Out:
# 0: 384x640 (no detections), 355.3ms
# Speed: 2.9ms preprocess, 355.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 333.7ms
# Speed: 3.9ms preprocess, 333.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 337.1ms
# Speed: 3.0ms preprocess, 337.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 368.2ms
# Speed: 3.3ms preprocess, 368.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 339.5ms
# Speed: 3.6ms preprocess, 339.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 guns, 348.0ms
# Speed: 2.8ms preprocess, 348.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 367.6ms
# Speed: 3.4ms preprocess, 367.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 342.5ms
# Speed: 3.7ms preprocess, 342.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 337.1ms
# Speed: 3.1ms preprocess, 337.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 359.5ms
# Speed: 4.6ms preprocess, 359.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 344.9ms
# Speed: 3.5ms preprocess, 344.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 349.9ms
# Speed: 4.0ms preprocess, 349.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 guns, 352.8ms
# Speed: 3.2ms preprocess, 352.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 guns, 340.3ms
# Speed: 3.4ms preprocess, 340.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 guns, 355.7ms
# Speed: 4.2ms preprocess, 355.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 346.3ms
# Speed: 3.3ms preprocess, 346.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 336.0ms
# Speed: 3.6ms preprocess, 336.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 435.8ms
# Speed: 3.5ms preprocess, 435.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# Email sent successfully!
#
# 0: 384x640 2 guns, 366.8ms
# Speed: 4.4ms preprocess, 366.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 guns, 346.3ms
# Speed: 3.5ms preprocess, 346.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 guns, 353.3ms
# Speed: 4.5ms preprocess, 353.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 348.9ms
# Speed: 3.7ms preprocess, 348.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 447.9ms
# Speed: 3.5ms preprocess, 447.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 539.6ms
# Speed: 4.3ms preprocess, 539.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 889.8ms
# Speed: 3.9ms preprocess, 889.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 738.7ms
# Speed: 6.8ms preprocess, 738.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 554.9ms
# Speed: 3.4ms preprocess, 554.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 428.2ms
# Speed: 3.6ms preprocess, 428.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 353.5ms
# Speed: 2.4ms preprocess, 353.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 356.6ms
# Speed: 3.2ms preprocess, 356.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 351.3ms
# Speed: 4.1ms preprocess, 351.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 358.0ms
# Speed: 4.0ms preprocess, 358.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 345.1ms
# Speed: 3.9ms preprocess, 345.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 341.7ms
# Speed: 3.4ms preprocess, 341.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 363.3ms
# Speed: 3.9ms preprocess, 363.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 349.1ms
# Speed: 3.2ms preprocess, 349.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 356.9ms
# Speed: 3.2ms preprocess, 356.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 355.3ms
# Speed: 3.7ms preprocess, 355.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 352.0ms
# Speed: 3.5ms preprocess, 352.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 351.9ms
# Speed: 3.4ms preprocess, 351.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.2ms
# Speed: 3.2ms preprocess, 354.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 346.5ms
# Speed: 4.3ms preprocess, 346.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 362.7ms
# Speed: 4.1ms preprocess, 362.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 346.1ms
# Speed: 3.2ms preprocess, 346.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 346.4ms
# Speed: 3.1ms preprocess, 346.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 364.7ms
# Speed: 3.2ms preprocess, 364.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 343.7ms
# Speed: 3.1ms preprocess, 343.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 346.3ms
# Speed: 3.7ms preprocess, 346.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 365.2ms
# Speed: 3.2ms preprocess, 365.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 346.6ms
# Speed: 3.1ms preprocess, 346.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 355.0ms
# Speed: 3.3ms preprocess, 355.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.3ms
# Speed: 3.1ms preprocess, 348.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 349.6ms
# Speed: 3.3ms preprocess, 349.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 362.2ms
# Speed: 3.5ms preprocess, 362.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 415.8ms
# Speed: 6.5ms preprocess, 415.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 568.6ms
# Speed: 6.6ms preprocess, 568.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 533.7ms
# Speed: 3.3ms preprocess, 533.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 533.7ms
# Speed: 3.4ms preprocess, 533.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 549.2ms
# Speed: 3.4ms preprocess, 549.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 569.4ms
# Speed: 3.3ms preprocess, 569.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 347.9ms
# Speed: 6.2ms preprocess, 347.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.1ms
# Speed: 3.3ms preprocess, 348.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 356.5ms
# Speed: 3.8ms preprocess, 356.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 341.7ms
# Speed: 3.1ms preprocess, 341.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 355.9ms
# Speed: 3.8ms preprocess, 355.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 352.1ms
# Speed: 3.4ms preprocess, 352.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 341.2ms
# Speed: 2.7ms preprocess, 341.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 356.3ms
# Speed: 4.3ms preprocess, 356.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 342.8ms
# Speed: 4.2ms preprocess, 342.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 363.1ms
# Speed: 3.2ms preprocess, 363.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 367.2ms
# Speed: 3.4ms preprocess, 367.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.0ms
# Speed: 3.4ms preprocess, 345.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.7ms
# Speed: 4.7ms preprocess, 354.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 645.1ms
# Speed: 4.0ms preprocess, 645.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 350.6ms
# Speed: 3.2ms preprocess, 350.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 628.0ms
# Speed: 3.4ms preprocess, 628.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 347.7ms
# Speed: 3.8ms preprocess, 347.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 581.5ms
# Speed: 3.3ms preprocess, 581.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 355.7ms
# Speed: 3.3ms preprocess, 355.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 364.4ms
# Speed: 3.2ms preprocess, 364.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 351.4ms
# Speed: 3.2ms preprocess, 351.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 553.8ms
# Speed: 4.5ms preprocess, 553.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 423.1ms
# Speed: 7.9ms preprocess, 423.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 710.5ms
# Speed: 3.8ms preprocess, 710.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 525.8ms
# Speed: 3.4ms preprocess, 525.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 545.0ms
# Speed: 3.4ms preprocess, 545.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 534.2ms
# Speed: 7.1ms preprocess, 534.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 540.9ms
# Speed: 3.3ms preprocess, 540.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 545.6ms
# Speed: 3.4ms preprocess, 545.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 413.2ms
# Speed: 3.9ms preprocess, 413.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 363.2ms
# Speed: 3.4ms preprocess, 363.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.6ms
# Speed: 3.5ms preprocess, 345.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 355.3ms
# Speed: 3.2ms preprocess, 355.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.4ms
# Speed: 3.2ms preprocess, 348.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 339.6ms
# Speed: 3.3ms preprocess, 339.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 368.0ms
# Speed: 3.5ms preprocess, 368.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 344.1ms
# Speed: 5.3ms preprocess, 344.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 343.1ms
# Speed: 4.3ms preprocess, 343.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 364.7ms
# Speed: 4.1ms preprocess, 364.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 346.8ms
# Speed: 3.6ms preprocess, 346.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 339.3ms
# Speed: 2.7ms preprocess, 339.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 361.4ms
# Speed: 4.3ms preprocess, 361.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 342.6ms
# Speed: 4.0ms preprocess, 342.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 350.9ms
# Speed: 4.1ms preprocess, 350.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 352.1ms
# Speed: 3.1ms preprocess, 352.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 343.1ms
# Speed: 3.1ms preprocess, 343.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 361.6ms
# Speed: 3.8ms preprocess, 361.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 340.5ms
# Speed: 4.1ms preprocess, 340.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 344.9ms
# Speed: 3.8ms preprocess, 344.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 356.9ms
# Speed: 3.2ms preprocess, 356.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 342.1ms
# Speed: 3.2ms preprocess, 342.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 343.1ms
# Speed: 3.1ms preprocess, 343.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 362.6ms
# Speed: 3.3ms preprocess, 362.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 340.8ms
# Speed: 2.7ms preprocess, 340.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 344.6ms
# Speed: 3.6ms preprocess, 344.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 365.0ms
# Speed: 3.2ms preprocess, 365.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 397.8ms
# Speed: 3.1ms preprocess, 397.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 567.6ms
# Speed: 3.3ms preprocess, 567.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 531.3ms
# Speed: 5.0ms preprocess, 531.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 549.8ms
# Speed: 3.5ms preprocess, 549.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 534.5ms
# Speed: 3.6ms preprocess, 534.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 559.4ms
# Speed: 4.5ms preprocess, 559.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 395.6ms
# Speed: 3.2ms preprocess, 395.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 358.9ms
# Speed: 3.2ms preprocess, 358.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 343.0ms
# Speed: 4.1ms preprocess, 343.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 353.9ms
# Speed: 3.3ms preprocess, 353.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 362.5ms
# Speed: 3.3ms preprocess, 362.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 341.5ms
# Speed: 3.4ms preprocess, 341.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 350.3ms
# Speed: 3.4ms preprocess, 350.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 352.1ms
# Speed: 3.2ms preprocess, 352.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 339.3ms
# Speed: 3.2ms preprocess, 339.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.7ms
# Speed: 3.9ms preprocess, 348.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 355.2ms
# Speed: 2.9ms preprocess, 355.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 343.4ms
# Speed: 3.8ms preprocess, 343.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 349.0ms
# Speed: 3.5ms preprocess, 349.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 359.8ms
# Speed: 3.4ms preprocess, 359.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.9ms
# Speed: 3.1ms preprocess, 348.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 337.1ms
# Speed: 3.5ms preprocess, 337.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 357.0ms
# Speed: 3.7ms preprocess, 357.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.8ms
# Speed: 4.2ms preprocess, 354.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 357.9ms
# Speed: 3.6ms preprocess, 357.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.3ms
# Speed: 4.1ms preprocess, 345.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.1ms
# Speed: 5.5ms preprocess, 354.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 357.8ms
# Speed: 3.6ms preprocess, 357.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 357.9ms
# Speed: 3.2ms preprocess, 357.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 344.6ms
# Speed: 3.4ms preprocess, 344.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 352.4ms
# Speed: 3.2ms preprocess, 352.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 356.1ms
# Speed: 3.2ms preprocess, 356.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 372.5ms
# Speed: 4.2ms preprocess, 372.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 432.9ms
# Speed: 3.2ms preprocess, 432.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 545.3ms
# Speed: 3.2ms preprocess, 545.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 550.0ms
# Speed: 3.3ms preprocess, 550.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 534.7ms
# Speed: 3.3ms preprocess, 534.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 557.0ms
# Speed: 3.2ms preprocess, 557.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 542.4ms
# Speed: 3.5ms preprocess, 542.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 361.5ms
# Speed: 3.3ms preprocess, 361.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.0ms
# Speed: 3.7ms preprocess, 345.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 351.3ms
# Speed: 4.6ms preprocess, 351.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.8ms
# Speed: 3.3ms preprocess, 354.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 342.6ms
# Speed: 3.6ms preprocess, 342.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 355.2ms
# Speed: 3.1ms preprocess, 355.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.7ms
# Speed: 4.0ms preprocess, 348.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 339.6ms
# Speed: 3.3ms preprocess, 339.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 361.6ms
# Speed: 2.9ms preprocess, 361.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 362.9ms
# Speed: 3.1ms preprocess, 362.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 337.3ms
# Speed: 3.2ms preprocess, 337.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 362.7ms
# Speed: 3.5ms preprocess, 362.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.0ms
# Speed: 3.3ms preprocess, 348.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 341.1ms
# Speed: 3.1ms preprocess, 341.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 359.8ms
# Speed: 5.9ms preprocess, 359.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.9ms
# Speed: 3.2ms preprocess, 345.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 370.1ms
# Speed: 3.1ms preprocess, 370.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 339.4ms
# Speed: 4.1ms preprocess, 339.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 343.6ms
# Speed: 4.2ms preprocess, 343.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 359.9ms
# Speed: 3.5ms preprocess, 359.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.7ms
# Speed: 3.2ms preprocess, 345.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 337.3ms
# Speed: 4.1ms preprocess, 337.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 367.8ms
# Speed: 3.3ms preprocess, 367.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 349.1ms
# Speed: 2.9ms preprocess, 349.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 337.7ms
# Speed: 4.6ms preprocess, 337.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 369.8ms
# Speed: 3.2ms preprocess, 369.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 342.2ms
# Speed: 3.8ms preprocess, 342.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 455.5ms
# Speed: 3.2ms preprocess, 455.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 531.4ms
# Speed: 6.6ms preprocess, 531.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 544.3ms
# Speed: 3.3ms preprocess, 544.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 525.0ms
# Speed: 3.3ms preprocess, 525.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 555.2ms
# Speed: 3.2ms preprocess, 555.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 536.6ms
# Speed: 3.3ms preprocess, 536.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 387.4ms
# Speed: 3.2ms preprocess, 387.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 344.1ms
# Speed: 3.8ms preprocess, 344.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 352.4ms
# Speed: 3.2ms preprocess, 352.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.8ms
# Speed: 3.8ms preprocess, 354.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 351.6ms
# Speed: 3.9ms preprocess, 351.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 352.0ms
# Speed: 3.8ms preprocess, 352.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.3ms
# Speed: 3.6ms preprocess, 354.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 333.6ms
# Speed: 3.3ms preprocess, 333.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 353.0ms
# Speed: 4.0ms preprocess, 353.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.6ms
# Speed: 3.4ms preprocess, 354.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 338.2ms
# Speed: 3.9ms preprocess, 338.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 362.6ms
# Speed: 3.5ms preprocess, 362.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 356.7ms
# Speed: 3.3ms preprocess, 356.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 347.6ms
# Speed: 2.9ms preprocess, 347.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 352.7ms
# Speed: 3.3ms preprocess, 352.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 344.9ms
# Speed: 4.0ms preprocess, 344.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 355.7ms
# Speed: 3.8ms preprocess, 355.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 359.6ms
# Speed: 4.6ms preprocess, 359.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.1ms
# Speed: 4.2ms preprocess, 345.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 368.4ms
# Speed: 3.8ms preprocess, 368.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 357.0ms
# Speed: 3.2ms preprocess, 357.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.4ms
# Speed: 3.6ms preprocess, 345.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 347.4ms
# Speed: 3.4ms preprocess, 347.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 357.0ms
# Speed: 3.2ms preprocess, 357.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 350.2ms
# Speed: 3.1ms preprocess, 350.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 355.4ms
# Speed: 3.5ms preprocess, 355.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 353.7ms
# Speed: 4.5ms preprocess, 353.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 481.2ms
# Speed: 3.4ms preprocess, 481.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 554.9ms
# Speed: 6.8ms preprocess, 554.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 539.1ms
# Speed: 3.4ms preprocess, 539.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 563.0ms
# Speed: 3.3ms preprocess, 563.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 549.0ms
# Speed: 3.2ms preprocess, 549.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 562.1ms
# Speed: 3.3ms preprocess, 562.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.4ms
# Speed: 3.2ms preprocess, 345.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 374.6ms
# Speed: 3.2ms preprocess, 374.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 359.1ms
# Speed: 3.4ms preprocess, 359.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 346.2ms
# Speed: 3.4ms preprocess, 346.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 361.4ms
# Speed: 3.1ms preprocess, 361.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 339.7ms
# Speed: 3.1ms preprocess, 339.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 350.3ms
# Speed: 3.2ms preprocess, 350.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 367.9ms
# Speed: 4.1ms preprocess, 367.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 346.9ms
# Speed: 3.7ms preprocess, 346.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 341.4ms
# Speed: 3.3ms preprocess, 341.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 361.7ms
# Speed: 3.1ms preprocess, 361.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 347.7ms
# Speed: 3.2ms preprocess, 347.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 336.9ms
# Speed: 4.7ms preprocess, 336.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 369.8ms
# Speed: 3.4ms preprocess, 369.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 339.2ms
# Speed: 3.9ms preprocess, 339.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 361.1ms
# Speed: 3.6ms preprocess, 361.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 351.6ms
# Speed: 3.3ms preprocess, 351.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 339.3ms
# Speed: 3.3ms preprocess, 339.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 363.5ms
# Speed: 3.4ms preprocess, 363.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 351.5ms
# Speed: 4.1ms preprocess, 351.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 349.8ms
# Speed: 3.1ms preprocess, 349.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 369.4ms
# Speed: 4.4ms preprocess, 369.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 342.7ms
# Speed: 3.3ms preprocess, 342.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.7ms
# Speed: 4.1ms preprocess, 348.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 370.3ms
# Speed: 3.4ms preprocess, 370.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 346.1ms
# Speed: 4.2ms preprocess, 346.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 341.3ms
# Speed: 3.6ms preprocess, 341.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 507.2ms
# Speed: 4.5ms preprocess, 507.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 546.7ms
# Speed: 3.3ms preprocess, 546.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 531.4ms
# Speed: 3.3ms preprocess, 531.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 546.1ms
# Speed: 3.4ms preprocess, 546.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 558.3ms
# Speed: 3.2ms preprocess, 558.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 511.1ms
# Speed: 3.3ms preprocess, 511.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 343.3ms
# Speed: 3.3ms preprocess, 343.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.1ms
# Speed: 3.2ms preprocess, 345.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 361.7ms
# Speed: 3.3ms preprocess, 361.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 338.3ms
# Speed: 4.0ms preprocess, 338.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 358.9ms
# Speed: 3.2ms preprocess, 358.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.7ms
# Speed: 3.3ms preprocess, 354.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 344.5ms
# Speed: 3.2ms preprocess, 344.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 361.6ms
# Speed: 3.2ms preprocess, 361.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 356.9ms
# Speed: 3.2ms preprocess, 356.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 344.1ms
# Speed: 3.9ms preprocess, 344.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 351.7ms
# Speed: 3.0ms preprocess, 351.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.9ms
# Speed: 8.0ms preprocess, 345.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 350.3ms
# Speed: 3.5ms preprocess, 350.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 363.0ms
# Speed: 3.9ms preprocess, 363.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 338.2ms
# Speed: 3.0ms preprocess, 338.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 362.4ms
# Speed: 4.2ms preprocess, 362.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.7ms
# Speed: 3.2ms preprocess, 354.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 342.4ms
# Speed: 4.3ms preprocess, 342.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 364.1ms
# Speed: 5.4ms preprocess, 364.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 358.0ms
# Speed: 4.8ms preprocess, 358.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 350.2ms
# Speed: 3.4ms preprocess, 350.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 353.0ms
# Speed: 4.0ms preprocess, 353.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 358.5ms
# Speed: 3.2ms preprocess, 358.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 357.0ms
# Speed: 3.3ms preprocess, 357.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.1ms
# Speed: 3.3ms preprocess, 354.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 349.0ms
# Speed: 4.7ms preprocess, 349.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.8ms
# Speed: 2.8ms preprocess, 354.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 542.2ms
# Speed: 3.2ms preprocess, 542.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 544.6ms
# Speed: 3.4ms preprocess, 544.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 525.9ms
# Speed: 4.8ms preprocess, 525.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 525.7ms
# Speed: 3.3ms preprocess, 525.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 549.1ms
# Speed: 4.7ms preprocess, 549.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 476.7ms
# Speed: 3.3ms preprocess, 476.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 351.2ms
# Speed: 4.3ms preprocess, 351.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 353.4ms
# Speed: 4.0ms preprocess, 353.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 344.5ms
# Speed: 3.9ms preprocess, 344.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 363.6ms
# Speed: 3.3ms preprocess, 363.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 343.5ms
# Speed: 3.7ms preprocess, 343.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 347.3ms
# Speed: 3.3ms preprocess, 347.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 367.6ms
# Speed: 3.9ms preprocess, 367.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 350.6ms
# Speed: 4.3ms preprocess, 350.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 358.2ms
# Speed: 3.2ms preprocess, 358.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 357.9ms
# Speed: 4.1ms preprocess, 357.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 346.4ms
# Speed: 4.3ms preprocess, 346.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 360.5ms
# Speed: 3.3ms preprocess, 360.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 373.2ms
# Speed: 3.4ms preprocess, 373.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.3ms
# Speed: 4.1ms preprocess, 348.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 364.0ms
# Speed: 2.4ms preprocess, 364.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 347.9ms
# Speed: 4.2ms preprocess, 347.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 340.2ms
# Speed: 4.0ms preprocess, 340.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 359.4ms
# Speed: 3.2ms preprocess, 359.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 350.7ms
# Speed: 3.7ms preprocess, 350.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 343.0ms
# Speed: 3.9ms preprocess, 343.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 370.8ms
# Speed: 3.9ms preprocess, 370.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.5ms
# Speed: 3.5ms preprocess, 348.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 363.8ms
# Speed: 3.2ms preprocess, 363.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 341.1ms
# Speed: 3.2ms preprocess, 341.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 342.7ms
# Speed: 4.3ms preprocess, 342.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 363.7ms
# Speed: 3.3ms preprocess, 363.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 370.0ms
# Speed: 3.1ms preprocess, 370.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 533.0ms
# Speed: 3.3ms preprocess, 533.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 540.3ms
# Speed: 3.3ms preprocess, 540.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 544.2ms
# Speed: 3.5ms preprocess, 544.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 538.8ms
# Speed: 5.5ms preprocess, 538.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 585.4ms
# Speed: 3.3ms preprocess, 585.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 443.8ms
# Speed: 4.7ms preprocess, 443.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 353.9ms
# Speed: 3.2ms preprocess, 353.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 359.4ms
# Speed: 3.4ms preprocess, 359.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 339.9ms
# Speed: 3.3ms preprocess, 339.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 367.9ms
# Speed: 3.6ms preprocess, 367.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 360.2ms
# Speed: 3.5ms preprocess, 360.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 347.3ms
# Speed: 3.6ms preprocess, 347.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 363.4ms
# Speed: 3.9ms preprocess, 363.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 344.9ms
# Speed: 3.4ms preprocess, 344.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 358.6ms
# Speed: 3.6ms preprocess, 358.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 362.6ms
# Speed: 4.2ms preprocess, 362.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 342.5ms
# Speed: 3.2ms preprocess, 342.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 gun, 360.4ms
# Speed: 3.3ms preprocess, 360.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a2393eddee28> in <cell line: 122>()
#     120 object_detection = ObjectDetection(video_path, sender_email, receiver_email, email_password, live_video_link)
#     121 # Run the detection
# --> 122 object_detection()
#
# <ipython-input-7-a2393eddee28> in __call__(self)
#      70                 break
#      71
# ---> 72             results = self.predict(im0)
#      73             im0, class_ids, confidences = self.plot_bboxes(results, im0)
#      74
#
# <ipython-input-7-a2393eddee28> in predict(self, im0)
#      28     def predict(self, im0):
#      29         """Run prediction using a YOLO model for the input image im0."""
# ---> 30         results = self.model(im0)
#      31         return results
#      32
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in __call__(self, source, stream, **kwargs)
#     174             ...     print(f"Detected {len(r)} objects in image")
#     175         """
# --> 176         return self.predict(source, stream, **kwargs)
#     177
#     178     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     552         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     553             self.predictor.set_prompts(prompts)
# --> 554         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     555
#     556     def track(
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     166             return self.stream_inference(source, model, *args, **kwargs)
#     167         else:
# --> 168             return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Result into one
#     169
#     170     def predict_cli(self, source=None, model=None):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in generator_context(*args, **kwargs)
#      34             # Issuing `None` to a generator fires it up
#      35             with ctx_factory():
# ---> 36                 response = gen.send(None)
#      37
#      38             while True:
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py in stream_inference(self, source, model, *args, **kwargs)
#     252                 # Inference
#     253                 with profilers[1]:
# --> 254                     preds = self.inference(im, *args, **kwargs)
#     255                     if self.args.embed:
#     256                         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py in inference(self, im, *args, **kwargs)
#     140             else False
#     141         )
# --> 142         return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#     143
#     144     def pre_transform(self, im):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/autobackend.py in forward(self, im, augment, visualize, embed)
#     463         # PyTorch
#     464         if self.pt or self.nn_module:
# --> 465             y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     466
#     467         # TorchScript
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py in forward(self, x, *args, **kwargs)
#     110         if isinstance(x, dict):  # for cases of training and validating while training.
#     111             return self.loss(x, *args, **kwargs)
# --> 112         return self.predict(x, *args, **kwargs)
#     113
#     114     def predict(self, x, profile=False, visualize=False, augment=False, embed=None):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py in predict(self, x, profile, visualize, augment, embed)
#     128         if augment:
#     129             return self._predict_augment(x)
# --> 130         return self._predict_once(x, profile, visualize, embed)
#     131
#     132     def _predict_once(self, x, profile=False, visualize=False, embed=None):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py in _predict_once(self, x, profile, visualize, embed)
#     149             if profile:
#     150                 self._profile_one_layer(m, x, dt)
# --> 151             x = m(x)  # run
#     152             y.append(x if m.i in self.save else None)  # save output
#     153             if visualize:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/modules/conv.py in forward_fuse(self, x)
#      52     def forward_fuse(self, x):
#      53         """Perform transposed convolution of 2D data."""
# ---> 54         return self.act(self.conv(x))
#      55
#      56
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# KeyboardInterrupt:
